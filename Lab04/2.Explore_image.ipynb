# %%
import cv2
import numpy as np

# Read JPG image
image = cv2.imread("images/foden.jpg")

# Check if image is loaded
if image is None:
    print("Error: Image not found")
else:
    print("Image loaded successfully")
# Out:
# Image loaded successfully

# %%
# Display image information
height, width, channels = image.shape
print("Height:", height)
print("Width:", width)
print("Channels:", channels)
print("Data type:", image.dtype)
# Out:
# Height: 251
# Width: 201
# Channels: 3
# Data type: uint8

# %%
# Save image in BMP format
cv2.imwrite("images/lenna.bmp", image)

print("JPG image successfully converted to BMP format")
# Out:
# JPG image successfully converted to BMP format

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# Read image
image = cv2.imread("images/foden.jpg")

# Print image properties
print("Image Shape (Height, Width, Channels):", image.shape)
print("Image Data Type:", image.dtype)

# Display pixel value at a specific location
x, y = 130, 140
for a in range(30):
    for b in range(30):
        print(f"Pixel value at ({x+a},{y+b}):", image[x+a, y+b])

# print(f"Pixel value at ({x},{y}):", image[x, y])
# Out:
# Image Shape (Height, Width, Channels): (251, 201, 3)
# Image Data Type: uint8
# Pixel value at (130,140): [ 5 11 18]
# Pixel value at (130,141): [23 25 26]
# Pixel value at (130,142): [36 32 31]
# Pixel value at (130,143): [33 28 25]
# Pixel value at (130,144): [30 25 24]
# Pixel value at (130,145): [30 24 25]
# Pixel value at (130,146): [30 24 25]
# Pixel value at (130,147): [30 24 25]
# Pixel value at (130,148): [30 24 25]
# Pixel value at (130,149): [30 24 25]
# Pixel value at (130,150): [30 24 25]
# Pixel value at (130,151): [30 24 25]
# Pixel value at (130,152): [30 24 25]
# Pixel value at (130,153): [30 24 25]
# Pixel value at (130,154): [30 24 25]
# Pixel value at (130,155): [30 24 25]
# Pixel value at (130,156): [30 24 25]
# Pixel value at (130,157): [30 24 25]
# Pixel value at (130,158): [30 24 25]
# Pixel value at (130,159): [30 24 25]
# Pixel value at (130,160): [28 23 22]
# Pixel value at (130,161): [28 23 22]
# Pixel value at (130,162): [28 23 22]
# Pixel value at (130,163): [27 22 21]
# Pixel value at (130,164): [27 22 21]
# Pixel value at (130,165): [27 22 21]
# Pixel value at (130,166): [26 21 20]
# Pixel value at (130,167): [26 21 20]
# Pixel value at (130,168): [27 22 21]
# Pixel value at (130,169): [27 22 21]
# Pixel value at (131,140): [22 28 35]
# Pixel value at (131,141): [25 24 26]
# Pixel value at (131,142): [25 22 18]
# Pixel value at (131,143): [29 24 21]
# Pixel value at (131,144): [30 25 24]
# Pixel value at (131,145): [30 24 25]
# Pixel value at (131,146): [30 24 25]
# Pixel value at (131,147): [30 24 25]
# Pixel value at (131,148): [30 24 25]
# Pixel value at (131,149): [30 24 25]
# Pixel value at (131,150): [30 24 25]
# Pixel value at (131,151): [30 24 25]
# Pixel value at (131,152): [30 24 25]
# Pixel value at (131,153): [30 24 25]
# Pixel value at (131,154): [30 24 25]
# Pixel value at (131,155): [30 24 25]
# Pixel value at (131,156): [30 24 25]
# Pixel value at (131,157): [30 24 25]
# Pixel value at (131,158): [30 24 25]
# Pixel value at (131,159): [30 24 25]
# Pixel value at (131,160): [28 23 22]
# Pixel value at (131,161): [28 23 22]
# Pixel value at (131,162): [28 23 22]
# Pixel value at (131,163): [27 22 21]
# Pixel value at (131,164): [27 22 21]
# Pixel value at (131,165): [27 22 21]
# Pixel value at (131,166): [26 21 20]
# Pixel value at (131,167): [26 21 20]
# Pixel value at (131,168): [27 22 21]
# Pixel value at (131,169): [27 22 21]
# Pixel value at (132,140): [26 30 35]
# Pixel value at (132,141): [29 27 27]
# Pixel value at (132,142): [22 17 14]
# Pixel value at (132,143): [27 20 17]
# Pixel value at (132,144): [30 25 24]
# Pixel value at (132,145): [30 24 25]
# Pixel value at (132,146): [30 24 25]
# Pixel value at (132,147): [30 24 25]
# Pixel value at (132,148): [30 24 25]
# Pixel value at (132,149): [30 24 25]
# Pixel value at (132,150): [30 24 25]
# Pixel value at (132,151): [30 24 25]
# Pixel value at (132,152): [30 24 25]
# Pixel value at (132,153): [30 24 25]
# Pixel value at (132,154): [30 24 25]
# Pixel value at (132,155): [30 24 25]
# Pixel value at (132,156): [30 24 25]
# Pixel value at (132,157): [30 24 25]
# Pixel value at (132,158): [30 24 25]
# Pixel value at (132,159): [30 24 25]
# Pixel value at (132,160): [28 23 22]
# Pixel value at (132,161): [28 23 22]
# Pixel value at (132,162): [28 23 22]
# Pixel value at (132,163): [27 22 21]
# Pixel value at (132,164): [27 22 21]
# Pixel value at (132,165): [27 22 21]
# Pixel value at (132,166): [26 21 20]
# Pixel value at (132,167): [26 21 20]
# Pixel value at (132,168): [27 22 21]
# Pixel value at (132,169): [27 22 21]
# Pixel value at (133,140): [13 16 21]
# Pixel value at (133,141): [33 31 31]
# Pixel value at (133,142): [32 25 22]
# Pixel value at (133,143): [28 19 16]
# Pixel value at (133,144): [32 24 24]
# Pixel value at (133,145): [30 24 25]
# Pixel value at (133,146): [30 24 25]
# Pixel value at (133,147): [30 24 25]
# Pixel value at (133,148): [30 24 25]
# Pixel value at (133,149): [30 24 25]
# Pixel value at (133,150): [30 24 25]
# Pixel value at (133,151): [30 24 25]
# Pixel value at (133,152): [30 24 25]
# Pixel value at (133,153): [30 24 25]
# Pixel value at (133,154): [30 24 25]
# Pixel value at (133,155): [30 24 25]
# Pixel value at (133,156): [30 24 25]
# Pixel value at (133,157): [30 24 25]
# Pixel value at (133,158): [30 24 25]
# Pixel value at (133,159): [30 24 25]
# Pixel value at (133,160): [28 23 22]
# Pixel value at (133,161): [28 23 22]
# Pixel value at (133,162): [28 23 22]
# Pixel value at (133,163): [27 22 21]
# Pixel value at (133,164): [27 22 21]
# Pixel value at (133,165): [27 22 21]
# Pixel value at (133,166): [26 21 20]
# Pixel value at (133,167): [26 21 20]
# Pixel value at (133,168): [27 22 21]
# Pixel value at (133,169): [27 22 21]
# Pixel value at (134,140): [15 16 20]
# Pixel value at (134,141): [33 29 28]
# Pixel value at (134,142): [39 30 26]
# Pixel value at (134,143): [29 20 16]
# Pixel value at (134,144): [32 24 24]
# Pixel value at (134,145): [30 24 25]
# Pixel value at (134,146): [30 24 25]
# Pixel value at (134,147): [30 24 25]
# Pixel value at (134,148): [30 24 25]
# Pixel value at (134,149): [30 24 25]
# Pixel value at (134,150): [30 24 25]
# Pixel value at (134,151): [30 24 25]
# Pixel value at (134,152): [30 24 25]
# Pixel value at (134,153): [30 24 25]
# Pixel value at (134,154): [30 24 25]
# Pixel value at (134,155): [30 24 25]
# Pixel value at (134,156): [30 24 25]
# Pixel value at (134,157): [30 24 25]
# Pixel value at (134,158): [30 24 25]
# Pixel value at (134,159): [30 24 25]
# Pixel value at (134,160): [28 23 22]
# Pixel value at (134,161): [28 23 22]
# Pixel value at (134,162): [28 23 22]
# Pixel value at (134,163): [27 22 21]
# Pixel value at (134,164): [27 22 21]
# Pixel value at (134,165): [27 22 21]
# Pixel value at (134,166): [26 21 20]
# Pixel value at (134,167): [26 21 20]
# Pixel value at (134,168): [27 22 21]
# Pixel value at (134,169): [27 22 21]
# Pixel value at (135,140): [30 29 31]
# Pixel value at (135,141): [28 23 22]
# Pixel value at (135,142): [35 26 22]
# Pixel value at (135,143): [30 21 17]
# Pixel value at (135,144): [32 24 24]
# Pixel value at (135,145): [30 24 25]
# Pixel value at (135,146): [30 24 25]
# Pixel value at (135,147): [30 24 25]
# Pixel value at (135,148): [30 24 25]
# Pixel value at (135,149): [30 24 25]
# Pixel value at (135,150): [30 24 25]
# Pixel value at (135,151): [30 24 25]
# Pixel value at (135,152): [30 24 25]
# Pixel value at (135,153): [30 24 25]
# Pixel value at (135,154): [30 24 25]
# Pixel value at (135,155): [30 24 25]
# Pixel value at (135,156): [30 24 25]
# Pixel value at (135,157): [30 24 25]
# Pixel value at (135,158): [30 24 25]
# Pixel value at (135,159): [30 24 25]
# Pixel value at (135,160): [28 23 22]
# Pixel value at (135,161): [28 23 22]
# Pixel value at (135,162): [28 23 22]
# Pixel value at (135,163): [27 22 21]
# Pixel value at (135,164): [27 22 21]
# Pixel value at (135,165): [27 22 21]
# Pixel value at (135,166): [26 21 20]
# Pixel value at (135,167): [26 21 20]
# Pixel value at (135,168): [27 22 21]
# Pixel value at (135,169): [27 22 21]
# Pixel value at (136,140): [19 16 18]
# Pixel value at (136,141): [22 17 16]
# Pixel value at (136,142): [30 21 17]
# Pixel value at (136,143): [38 29 26]
# Pixel value at (136,144): [32 24 24]
# Pixel value at (136,145): [30 24 25]
# Pixel value at (136,146): [30 24 25]
# Pixel value at (136,147): [30 24 25]
# Pixel value at (136,148): [30 24 25]
# Pixel value at (136,149): [30 24 25]
# Pixel value at (136,150): [30 24 25]
# Pixel value at (136,151): [30 24 25]
# Pixel value at (136,152): [28 22 23]
# Pixel value at (136,153): [28 22 23]
# Pixel value at (136,154): [28 22 23]
# Pixel value at (136,155): [28 22 23]
# Pixel value at (136,156): [28 22 23]
# Pixel value at (136,157): [28 22 23]
# Pixel value at (136,158): [28 22 23]
# Pixel value at (136,159): [28 22 23]
# Pixel value at (136,160): [27 22 21]
# Pixel value at (136,161): [27 22 21]
# Pixel value at (136,162): [27 22 21]
# Pixel value at (136,163): [27 22 21]
# Pixel value at (136,164): [27 22 21]
# Pixel value at (136,165): [27 22 21]
# Pixel value at (136,166): [27 22 21]
# Pixel value at (136,167): [27 22 21]
# Pixel value at (136,168): [28 23 22]
# Pixel value at (136,169): [28 23 22]
# Pixel value at (137,140): [26 21 22]
# Pixel value at (137,141): [32 24 24]
# Pixel value at (137,142): [29 20 17]
# Pixel value at (137,143): [19 10  7]
# Pixel value at (137,144): [31 23 23]
# Pixel value at (137,145): [29 23 24]
# Pixel value at (137,146): [29 23 24]
# Pixel value at (137,147): [29 23 24]
# Pixel value at (137,148): [29 23 24]
# Pixel value at (137,149): [29 23 24]
# Pixel value at (137,150): [29 23 24]
# Pixel value at (137,151): [29 23 24]
# Pixel value at (137,152): [28 22 23]
# Pixel value at (137,153): [28 22 23]
# Pixel value at (137,154): [28 22 23]
# Pixel value at (137,155): [28 22 23]
# Pixel value at (137,156): [28 22 23]
# Pixel value at (137,157): [28 22 23]
# Pixel value at (137,158): [28 22 23]
# Pixel value at (137,159): [28 22 23]
# Pixel value at (137,160): [27 22 21]
# Pixel value at (137,161): [27 22 21]
# Pixel value at (137,162): [27 22 21]
# Pixel value at (137,163): [27 22 21]
# Pixel value at (137,164): [27 22 21]
# Pixel value at (137,165): [27 22 21]
# Pixel value at (137,166): [27 22 21]
# Pixel value at (137,167): [27 22 21]
# Pixel value at (137,168): [28 23 22]
# Pixel value at (137,169): [28 23 22]
# Pixel value at (138,140): [15  9 10]
# Pixel value at (138,141): [34 26 26]
# Pixel value at (138,142): [38 29 26]
# Pixel value at (138,143): [29 20 17]
# Pixel value at (138,144): [31 23 23]
# Pixel value at (138,145): [29 23 24]
# Pixel value at (138,146): [29 23 24]
# Pixel value at (138,147): [29 23 24]
# Pixel value at (138,148): [29 23 24]
# Pixel value at (138,149): [29 23 24]
# Pixel value at (138,150): [29 23 24]
# Pixel value at (138,151): [29 23 24]
# Pixel value at (138,152): [28 22 23]
# Pixel value at (138,153): [28 22 23]
# Pixel value at (138,154): [28 22 23]
# Pixel value at (138,155): [28 22 23]
# Pixel value at (138,156): [28 22 23]
# Pixel value at (138,157): [28 22 23]
# Pixel value at (138,158): [28 22 23]
# Pixel value at (138,159): [28 22 23]
# Pixel value at (138,160): [27 22 21]
# Pixel value at (138,161): [27 22 21]
# Pixel value at (138,162): [27 22 21]
# Pixel value at (138,163): [27 22 21]
# Pixel value at (138,164): [27 22 21]
# Pixel value at (138,165): [27 22 21]
# Pixel value at (138,166): [27 22 21]
# Pixel value at (138,167): [27 22 21]
# Pixel value at (138,168): [28 23 22]
# Pixel value at (138,169): [28 23 22]
# Pixel value at (139,140): [28 23 22]
# Pixel value at (139,141): [30 22 22]
# Pixel value at (139,142): [28 19 16]
# Pixel value at (139,143): [29 21 21]
# Pixel value at (139,144): [29 23 24]
# Pixel value at (139,145): [29 23 24]
# Pixel value at (139,146): [29 23 24]
# Pixel value at (139,147): [29 23 24]
# Pixel value at (139,148): [29 23 24]
# Pixel value at (139,149): [29 23 24]
# Pixel value at (139,150): [29 23 24]
# Pixel value at (139,151): [29 23 24]
# Pixel value at (139,152): [28 22 23]
# Pixel value at (139,153): [28 22 23]
# Pixel value at (139,154): [28 22 23]
# Pixel value at (139,155): [28 22 23]
# Pixel value at (139,156): [28 22 23]
# Pixel value at (139,157): [28 22 23]
# Pixel value at (139,158): [28 22 23]
# Pixel value at (139,159): [28 22 23]
# Pixel value at (139,160): [27 22 21]
# Pixel value at (139,161): [27 22 21]
# Pixel value at (139,162): [27 22 21]
# Pixel value at (139,163): [27 22 21]
# Pixel value at (139,164): [27 22 21]
# Pixel value at (139,165): [27 22 21]
# Pixel value at (139,166): [27 22 21]
# Pixel value at (139,167): [27 22 21]
# Pixel value at (139,168): [28 23 22]
# Pixel value at (139,169): [28 23 22]
# Pixel value at (140,140): [32 24 24]
# Pixel value at (140,141): [24 16 16]
# Pixel value at (140,142): [31 23 23]
# Pixel value at (140,143): [47 39 39]
# Pixel value at (140,144): [28 22 23]
# Pixel value at (140,145): [28 22 23]
# Pixel value at (140,146): [28 22 23]
# Pixel value at (140,147): [28 22 23]
# Pixel value at (140,148): [28 22 23]
# Pixel value at (140,149): [28 22 23]
# Pixel value at (140,150): [28 22 23]
# Pixel value at (140,151): [28 22 23]
# Pixel value at (140,152): [28 22 23]
# Pixel value at (140,153): [28 22 23]
# Pixel value at (140,154): [28 22 23]
# Pixel value at (140,155): [28 22 23]
# Pixel value at (140,156): [28 22 23]
# Pixel value at (140,157): [28 22 23]
# Pixel value at (140,158): [28 22 23]
# Pixel value at (140,159): [28 22 23]
# Pixel value at (140,160): [27 22 21]
# Pixel value at (140,161): [27 22 21]
# Pixel value at (140,162): [27 22 21]
# Pixel value at (140,163): [27 22 21]
# Pixel value at (140,164): [27 22 21]
# Pixel value at (140,165): [27 22 21]
# Pixel value at (140,166): [27 22 21]
# Pixel value at (140,167): [27 22 21]
# Pixel value at (140,168): [28 23 22]
# Pixel value at (140,169): [28 23 22]
# Pixel value at (141,140): [34 26 26]
# Pixel value at (141,141): [32 24 24]
# Pixel value at (141,142): [35 27 27]
# Pixel value at (141,143): [30 22 22]
# Pixel value at (141,144): [28 22 23]
# Pixel value at (141,145): [28 22 23]
# Pixel value at (141,146): [28 22 23]
# Pixel value at (141,147): [28 22 23]
# Pixel value at (141,148): [28 22 23]
# Pixel value at (141,149): [28 22 23]
# Pixel value at (141,150): [28 22 23]
# Pixel value at (141,151): [28 22 23]
# Pixel value at (141,152): [28 22 23]
# Pixel value at (141,153): [28 22 23]
# Pixel value at (141,154): [28 22 23]
# Pixel value at (141,155): [28 22 23]
# Pixel value at (141,156): [28 22 23]
# Pixel value at (141,157): [28 22 23]
# Pixel value at (141,158): [28 22 23]
# Pixel value at (141,159): [28 22 23]
# Pixel value at (141,160): [27 22 21]
# Pixel value at (141,161): [27 22 21]
# Pixel value at (141,162): [27 22 21]
# Pixel value at (141,163): [27 22 21]
# Pixel value at (141,164): [27 22 21]
# Pixel value at (141,165): [27 22 21]
# Pixel value at (141,166): [27 22 21]
# Pixel value at (141,167): [27 22 21]
# Pixel value at (141,168): [28 23 22]
# Pixel value at (141,169): [28 23 22]
# Pixel value at (142,140): [29 21 21]
# Pixel value at (142,141): [31 23 23]
# Pixel value at (142,142): [34 26 27]
# Pixel value at (142,143): [13  5  6]
# Pixel value at (142,144): [27 21 22]
# Pixel value at (142,145): [27 21 22]
# Pixel value at (142,146): [27 21 22]
# Pixel value at (142,147): [27 21 22]
# Pixel value at (142,148): [27 21 22]
# Pixel value at (142,149): [27 21 22]
# Pixel value at (142,150): [27 21 22]
# Pixel value at (142,151): [27 21 22]
# Pixel value at (142,152): [28 22 23]
# Pixel value at (142,153): [28 22 23]
# Pixel value at (142,154): [28 22 23]
# Pixel value at (142,155): [28 22 23]
# Pixel value at (142,156): [28 22 23]
# Pixel value at (142,157): [28 22 23]
# Pixel value at (142,158): [28 22 23]
# Pixel value at (142,159): [28 22 23]
# Pixel value at (142,160): [27 22 21]
# Pixel value at (142,161): [27 22 21]
# Pixel value at (142,162): [27 22 21]
# Pixel value at (142,163): [27 22 21]
# Pixel value at (142,164): [27 22 21]
# Pixel value at (142,165): [27 22 21]
# Pixel value at (142,166): [27 22 21]
# Pixel value at (142,167): [27 22 21]
# Pixel value at (142,168): [28 23 22]
# Pixel value at (142,169): [28 23 22]
# Pixel value at (143,140): [26 21 22]
# Pixel value at (143,141): [4 0 0]
# Pixel value at (143,142): [7 2 4]
# Pixel value at (143,143): [4 0 1]
# Pixel value at (143,144): [26 21 22]
# Pixel value at (143,145): [26 21 22]
# Pixel value at (143,146): [26 21 22]
# Pixel value at (143,147): [26 21 22]
# Pixel value at (143,148): [26 21 22]
# Pixel value at (143,149): [26 21 22]
# Pixel value at (143,150): [27 21 22]
# Pixel value at (143,151): [27 21 22]
# Pixel value at (143,152): [28 22 23]
# Pixel value at (143,153): [28 22 23]
# Pixel value at (143,154): [28 22 23]
# Pixel value at (143,155): [28 22 23]
# Pixel value at (143,156): [28 22 23]
# Pixel value at (143,157): [28 22 23]
# Pixel value at (143,158): [28 22 23]
# Pixel value at (143,159): [28 22 23]
# Pixel value at (143,160): [27 22 21]
# Pixel value at (143,161): [27 22 21]
# Pixel value at (143,162): [29 21 21]
# Pixel value at (143,163): [27 22 21]
# Pixel value at (143,164): [29 21 21]
# Pixel value at (143,165): [27 22 21]
# Pixel value at (143,166): [29 21 21]
# Pixel value at (143,167): [27 22 21]
# Pixel value at (143,168): [30 22 22]
# Pixel value at (143,169): [28 23 22]
# Pixel value at (144,140): [242 245 249]
# Pixel value at (144,141): [222 225 229]
# Pixel value at (144,142): [182 185 189]
# Pixel value at (144,143): [147 148 152]
# Pixel value at (144,144): [57 56 58]
# Pixel value at (144,145): [16 14 14]
# Pixel value at (144,146): [2 0 0]
# Pixel value at (144,147): [12 10 10]
# Pixel value at (144,148): [17 15 15]
# Pixel value at (144,149): [20 18 18]
# Pixel value at (144,150): [28 23 24]
# Pixel value at (144,151): [26 21 22]
# Pixel value at (144,152): [30 25 26]
# Pixel value at (144,153): [30 25 26]
# Pixel value at (144,154): [31 25 26]
# Pixel value at (144,155): [30 24 25]
# Pixel value at (144,156): [30 24 25]
# Pixel value at (144,157): [29 23 24]
# Pixel value at (144,158): [29 23 24]
# Pixel value at (144,159): [29 23 24]
# Pixel value at (144,160): [28 20 21]
# Pixel value at (144,161): [27 19 20]
# Pixel value at (144,162): [29 18 20]
# Pixel value at (144,163): [30 22 23]
# Pixel value at (144,164): [35 24 26]
# Pixel value at (144,165): [32 24 25]
# Pixel value at (144,166): [28 17 19]
# Pixel value at (144,167): [20 12 13]
# Pixel value at (144,168): [36 25 27]
# Pixel value at (144,169): [22 14 15]
# Pixel value at (145,140): [226 232 237]
# Pixel value at (145,141): [226 232 237]
# Pixel value at (145,142): [229 235 240]
# Pixel value at (145,143): [233 238 241]
# Pixel value at (145,144): [245 247 248]
# Pixel value at (145,145): [217 219 219]
# Pixel value at (145,146): [182 182 182]
# Pixel value at (145,147): [124 124 124]
# Pixel value at (145,148): [54 54 54]
# Pixel value at (145,149): [18 16 16]
# Pixel value at (145,150): [13 11 11]
# Pixel value at (145,151): [11  9  9]
# Pixel value at (145,152): [21 19 19]
# Pixel value at (145,153): [24 19 20]
# Pixel value at (145,154): [25 20 21]
# Pixel value at (145,155): [27 22 23]
# Pixel value at (145,156): [30 24 25]
# Pixel value at (145,157): [31 25 26]
# Pixel value at (145,158): [32 26 27]
# Pixel value at (145,159): [33 27 28]
# Pixel value at (145,160): [20 12 13]
# Pixel value at (145,161): [26 18 19]
# Pixel value at (145,162): [36 25 27]
# Pixel value at (145,163): [37 29 30]
# Pixel value at (145,164): [38 27 29]
# Pixel value at (145,165): [32 24 25]
# Pixel value at (145,166): [31 20 22]
# Pixel value at (145,167): [29 21 22]
# Pixel value at (145,168): [31 20 22]
# Pixel value at (145,169): [44 36 37]
# Pixel value at (146,140): [220 226 231]
# Pixel value at (146,141): [215 221 226]
# Pixel value at (146,142): [224 230 235]
# Pixel value at (146,143): [240 245 248]
# Pixel value at (146,144): [233 237 238]
# Pixel value at (146,145): [231 236 235]
# Pixel value at (146,146): [241 243 243]
# Pixel value at (146,147): [253 255 255]
# Pixel value at (146,148): [253 255 255]
# Pixel value at (146,149): [220 220 220]
# Pixel value at (146,150): [131 131 131]
# Pixel value at (146,151): [39 39 39]
# Pixel value at (146,152): [3 3 3]
# Pixel value at (146,153): [6 4 4]
# Pixel value at (146,154): [7 5 5]
# Pixel value at (146,155): [8 6 6]
# Pixel value at (146,156): [11  6  7]
# Pixel value at (146,157): [13  8  9]
# Pixel value at (146,158): [14  9 10]
# Pixel value at (146,159): [15  9 10]
# Pixel value at (146,160): [21 15 16]
# Pixel value at (146,161): [22 16 17]
# Pixel value at (146,162): [27 19 20]
# Pixel value at (146,163): [29 23 24]
# Pixel value at (146,164): [34 26 27]
# Pixel value at (146,165): [31 25 26]
# Pixel value at (146,166): [29 21 22]
# Pixel value at (146,167): [24 18 19]
# Pixel value at (146,168): [27 19 20]
# Pixel value at (146,169): [34 28 29]
# Pixel value at (147,140): [233 239 244]
# Pixel value at (147,141): [224 230 235]
# Pixel value at (147,142): [219 225 230]
# Pixel value at (147,143): [221 228 231]
# Pixel value at (147,144): [230 235 236]
# Pixel value at (147,145): [238 244 243]
# Pixel value at (147,146): [237 242 241]
# Pixel value at (147,147): [224 229 228]
# Pixel value at (147,148): [224 229 228]
# Pixel value at (147,149): [245 247 247]
# Pixel value at (147,150): [253 255 255]
# Pixel value at (147,151): [250 252 252]
# Pixel value at (147,152): [150 152 152]
# Pixel value at (147,153): [145 145 145]
# Pixel value at (147,154): [132 132 132]
# Pixel value at (147,155): [115 115 115]
# Pixel value at (147,156): [99 97 97]
# Pixel value at (147,157): [82 80 80]
# Pixel value at (147,158): [69 67 67]
# Pixel value at (147,159): [62 60 60]
# Pixel value at (147,160): [55 50 51]
# Pixel value at (147,161): [31 26 27]
# Pixel value at (147,162): [4 0 0]
# Pixel value at (147,163): [4 0 0]
# Pixel value at (147,164): [7 2 3]
# Pixel value at (147,165): [19 14 15]
# Pixel value at (147,166): [21 16 17]
# Pixel value at (147,167): [17 12 13]
# Pixel value at (147,168): [40 35 36]
# Pixel value at (147,169): [22 17 18]
# Pixel value at (148,140): [238 244 249]
# Pixel value at (148,141): [238 244 249]
# Pixel value at (148,142): [235 241 246]
# Pixel value at (148,143): [236 243 246]
# Pixel value at (148,144): [228 236 236]
# Pixel value at (148,145): [234 242 241]
# Pixel value at (148,146): [237 243 242]
# Pixel value at (148,147): [237 243 242]
# Pixel value at (148,148): [240 246 245]
# Pixel value at (148,149): [240 245 244]
# Pixel value at (148,150): [233 238 237]
# Pixel value at (148,151): [227 232 231]
# Pixel value at (148,152): [247 252 251]
# Pixel value at (148,153): [249 251 251]
# Pixel value at (148,154): [249 251 251]
# Pixel value at (148,155): [249 251 251]
# Pixel value at (148,156): [250 250 250]
# Pixel value at (148,157): [250 250 250]
# Pixel value at (148,158): [250 250 250]
# Pixel value at (148,159): [250 250 250]
# Pixel value at (148,160): [255 255 255]
# Pixel value at (148,161): [251 249 249]
# Pixel value at (148,162): [238 236 236]
# Pixel value at (148,163): [227 225 225]
# Pixel value at (148,164): [210 208 208]
# Pixel value at (148,165): [173 171 171]
# Pixel value at (148,166): [121 119 119]
# Pixel value at (148,167): [83 81 81]
# Pixel value at (148,168): [2 0 0]
# Pixel value at (148,169): [7 5 5]
# Pixel value at (149,140): [226 232 237]
# Pixel value at (149,141): [228 234 239]
# Pixel value at (149,142): [232 238 243]
# Pixel value at (149,143): [237 244 247]
# Pixel value at (149,144): [229 237 237]
# Pixel value at (149,145): [231 242 240]
# Pixel value at (149,146): [232 240 239]
# Pixel value at (149,147): [229 237 236]
# Pixel value at (149,148): [227 235 234]
# Pixel value at (149,149): [219 227 226]
# Pixel value at (149,150): [225 231 230]
# Pixel value at (149,151): [242 248 247]
# Pixel value at (149,152): [235 241 240]
# Pixel value at (149,153): [237 242 241]
# Pixel value at (149,154): [239 244 243]
# Pixel value at (149,155): [242 247 246]
# Pixel value at (149,156): [246 248 248]
# Pixel value at (149,157): [247 252 251]
# Pixel value at (149,158): [250 252 252]
# Pixel value at (149,159): [251 253 253]
# Pixel value at (149,160): [245 247 247]
# Pixel value at (149,161): [246 248 248]
# Pixel value at (149,162): [247 249 249]
# Pixel value at (149,163): [251 253 253]
# Pixel value at (149,164): [253 255 255]
# Pixel value at (149,165): [253 255 255]
# Pixel value at (149,166): [253 255 255]
# Pixel value at (149,167): [253 255 255]
# Pixel value at (149,168): [224 226 226]
# Pixel value at (149,169): [152 154 154]
# Pixel value at (150,140): [218 224 229]
# Pixel value at (150,141): [223 229 234]
# Pixel value at (150,142): [229 235 240]
# Pixel value at (150,143): [231 238 241]
# Pixel value at (150,144): [229 239 239]
# Pixel value at (150,145): [231 243 243]
# Pixel value at (150,146): [230 240 240]
# Pixel value at (150,147): [234 244 244]
# Pixel value at (150,148): [242 252 252]
# Pixel value at (150,149): [231 241 241]
# Pixel value at (150,150): [221 229 229]
# Pixel value at (150,151): [227 235 235]
# Pixel value at (150,152): [232 240 240]
# Pixel value at (150,153): [234 239 240]
# Pixel value at (150,154): [235 240 241]
# Pixel value at (150,155): [235 240 241]
# Pixel value at (150,156): [237 241 242]
# Pixel value at (150,157): [237 242 243]
# Pixel value at (150,158): [238 242 243]
# Pixel value at (150,159): [239 243 244]
# Pixel value at (150,160): [248 252 253]
# Pixel value at (150,161): [249 253 254]
# Pixel value at (150,162): [248 252 253]
# Pixel value at (150,163): [244 248 249]
# Pixel value at (150,164): [238 242 243]
# Pixel value at (150,165): [234 238 239]
# Pixel value at (150,166): [234 238 239]
# Pixel value at (150,167): [236 240 241]
# Pixel value at (150,168): [242 246 247]
# Pixel value at (150,169): [251 255 255]
# Pixel value at (151,140): [216 222 227]
# Pixel value at (151,141): [224 230 235]
# Pixel value at (151,142): [226 232 237]
# Pixel value at (151,143): [219 228 232]
# Pixel value at (151,144): [233 245 247]
# Pixel value at (151,145): [238 250 250]
# Pixel value at (151,146): [229 241 241]
# Pixel value at (151,147): [225 237 237]
# Pixel value at (151,148): [236 246 246]
# Pixel value at (151,149): [233 243 243]
# Pixel value at (151,150): [228 238 238]
# Pixel value at (151,151): [237 247 247]
# Pixel value at (151,152): [228 236 236]
# Pixel value at (151,153): [229 237 237]
# Pixel value at (151,154): [233 238 239]
# Pixel value at (151,155): [235 240 241]
# Pixel value at (151,156): [238 243 244]
# Pixel value at (151,157): [240 245 246]
# Pixel value at (151,158): [242 247 248]
# Pixel value at (151,159): [243 248 249]
# Pixel value at (151,160): [242 247 248]
# Pixel value at (151,161): [241 246 247]
# Pixel value at (151,162): [242 247 248]
# Pixel value at (151,163): [246 251 252]
# Pixel value at (151,164): [250 255 255]
# Pixel value at (151,165): [250 255 255]
# Pixel value at (151,166): [249 254 255]
# Pixel value at (151,167): [245 250 251]
# Pixel value at (151,168): [250 255 255]
# Pixel value at (151,169): [229 234 235]
# Pixel value at (152,140): [211 217 222]
# Pixel value at (152,141): [216 222 227]
# Pixel value at (152,142): [223 229 234]
# Pixel value at (152,143): [221 230 234]
# Pixel value at (152,144): [225 237 239]
# Pixel value at (152,145): [224 237 239]
# Pixel value at (152,146): [224 237 239]
# Pixel value at (152,147): [225 238 240]
# Pixel value at (152,148): [226 238 240]
# Pixel value at (152,149): [227 239 241]
# Pixel value at (152,150): [229 238 241]
# Pixel value at (152,151): [229 238 241]
# Pixel value at (152,152): [229 238 241]
# Pixel value at (152,153): [229 238 241]
# Pixel value at (152,154): [232 239 242]
# Pixel value at (152,155): [232 239 242]
# Pixel value at (152,156): [233 240 243]
# Pixel value at (152,157): [234 241 244]
# Pixel value at (152,158): [237 242 245]
# Pixel value at (152,159): [237 242 245]
# Pixel value at (152,160): [241 248 251]
# Pixel value at (152,161): [242 249 252]
# Pixel value at (152,162): [242 249 252]
# Pixel value at (152,163): [242 249 252]
# Pixel value at (152,164): [243 250 253]
# Pixel value at (152,165): [243 250 253]
# Pixel value at (152,166): [243 250 253]
# Pixel value at (152,167): [244 251 254]
# Pixel value at (152,168): [244 251 254]
# Pixel value at (152,169): [244 251 254]
# Pixel value at (153,140): [215 221 226]
# Pixel value at (153,141): [217 223 228]
# Pixel value at (153,142): [222 228 233]
# Pixel value at (153,143): [224 233 237]
# Pixel value at (153,144): [224 236 238]
# Pixel value at (153,145): [223 236 238]
# Pixel value at (153,146): [224 237 239]
# Pixel value at (153,147): [225 238 240]
# Pixel value at (153,148): [227 239 241]
# Pixel value at (153,149): [227 239 241]
# Pixel value at (153,150): [230 239 242]
# Pixel value at (153,151): [230 239 242]
# Pixel value at (153,152): [231 240 243]
# Pixel value at (153,153): [231 240 243]
# Pixel value at (153,154): [234 241 244]
# Pixel value at (153,155): [235 242 245]
# Pixel value at (153,156): [235 242 245]
# Pixel value at (153,157): [236 243 246]
# Pixel value at (153,158): [239 244 247]
# Pixel value at (153,159): [239 244 247]
# Pixel value at (153,160): [241 248 251]
# Pixel value at (153,161): [242 249 252]
# Pixel value at (153,162): [242 249 252]
# Pixel value at (153,163): [242 249 252]
# Pixel value at (153,164): [243 250 253]
# Pixel value at (153,165): [243 250 253]
# Pixel value at (153,166): [243 250 253]
# Pixel value at (153,167): [244 251 254]
# Pixel value at (153,168): [244 251 254]
# Pixel value at (153,169): [244 251 254]
# Pixel value at (154,140): [220 226 231]
# Pixel value at (154,141): [217 223 228]
# Pixel value at (154,142): [221 227 232]
# Pixel value at (154,143): [227 236 240]
# Pixel value at (154,144): [223 235 237]
# Pixel value at (154,145): [224 236 238]
# Pixel value at (154,146): [224 236 238]
# Pixel value at (154,147): [226 238 240]
# Pixel value at (154,148): [229 238 241]
# Pixel value at (154,149): [230 239 242]
# Pixel value at (154,150): [231 240 243]
# Pixel value at (154,151): [231 240 243]
# Pixel value at (154,152): [236 243 246]
# Pixel value at (154,153): [236 243 246]
# Pixel value at (154,154): [239 244 247]
# Pixel value at (154,155): [240 245 248]
# Pixel value at (154,156): [241 246 249]
# Pixel value at (154,157): [241 246 249]
# Pixel value at (154,158): [242 247 250]
# Pixel value at (154,159): [242 247 250]
# Pixel value at (154,160): [241 248 251]
# Pixel value at (154,161): [242 249 252]
# Pixel value at (154,162): [242 249 252]
# Pixel value at (154,163): [242 249 252]
# Pixel value at (154,164): [243 250 253]
# Pixel value at (154,165): [243 250 253]
# Pixel value at (154,166): [243 250 253]
# Pixel value at (154,167): [244 251 254]
# Pixel value at (154,168): [244 251 254]
# Pixel value at (154,169): [244 251 254]
# Pixel value at (155,140): [225 231 236]
# Pixel value at (155,141): [218 224 229]
# Pixel value at (155,142): [221 227 232]
# Pixel value at (155,143): [230 236 241]
# Pixel value at (155,144): [224 233 236]
# Pixel value at (155,145): [222 234 236]
# Pixel value at (155,146): [224 236 238]
# Pixel value at (155,147): [225 237 239]
# Pixel value at (155,148): [229 238 241]
# Pixel value at (155,149): [231 240 243]
# Pixel value at (155,150): [232 241 244]
# Pixel value at (155,151): [235 242 245]
# Pixel value at (155,152): [239 246 249]
# Pixel value at (155,153): [239 246 249]
# Pixel value at (155,154): [242 247 250]
# Pixel value at (155,155): [243 248 251]
# Pixel value at (155,156): [243 248 251]
# Pixel value at (155,157): [244 249 252]
# Pixel value at (155,158): [245 250 253]
# Pixel value at (155,159): [245 250 253]
# Pixel value at (155,160): [243 248 251]
# Pixel value at (155,161): [242 249 252]
# Pixel value at (155,162): [242 249 252]
# Pixel value at (155,163): [242 249 252]
# Pixel value at (155,164): [243 250 253]
# Pixel value at (155,165): [243 250 253]
# Pixel value at (155,166): [243 250 253]
# Pixel value at (155,167): [244 251 254]
# Pixel value at (155,168): [244 251 254]
# Pixel value at (155,169): [244 251 254]
# Pixel value at (156,140): [225 231 236]
# Pixel value at (156,141): [220 226 231]
# Pixel value at (156,142): [221 227 232]
# Pixel value at (156,143): [228 234 239]
# Pixel value at (156,144): [222 231 235]
# Pixel value at (156,145): [223 232 236]
# Pixel value at (156,146): [225 234 238]
# Pixel value at (156,147): [227 236 240]
# Pixel value at (156,148): [231 237 242]
# Pixel value at (156,149): [234 240 245]
# Pixel value at (156,150): [235 241 246]
# Pixel value at (156,151): [238 242 247]
# Pixel value at (156,152): [242 246 251]
# Pixel value at (156,153): [243 247 252]
# Pixel value at (156,154): [244 247 252]
# Pixel value at (156,155): [245 248 253]
# Pixel value at (156,156): [246 249 254]
# Pixel value at (156,157): [247 250 255]
# Pixel value at (156,158): [247 250 255]
# Pixel value at (156,159): [248 251 255]
# Pixel value at (156,160): [243 247 252]
# Pixel value at (156,161): [244 248 253]
# Pixel value at (156,162): [244 248 253]
# Pixel value at (156,163): [244 248 253]
# Pixel value at (156,164): [245 249 254]
# Pixel value at (156,165): [245 249 254]
# Pixel value at (156,166): [245 249 254]
# Pixel value at (156,167): [246 250 255]
# Pixel value at (156,168): [246 250 255]
# Pixel value at (156,169): [246 250 255]
# Pixel value at (157,140): [222 228 233]
# Pixel value at (157,141): [222 228 233]
# Pixel value at (157,142): [221 227 232]
# Pixel value at (157,143): [222 228 233]
# Pixel value at (157,144): [221 230 234]
# Pixel value at (157,145): [222 231 235]
# Pixel value at (157,146): [224 233 237]
# Pixel value at (157,147): [229 235 240]
# Pixel value at (157,148): [232 238 243]
# Pixel value at (157,149): [234 240 245]
# Pixel value at (157,150): [238 242 247]
# Pixel value at (157,151): [239 243 248]
# Pixel value at (157,152): [242 246 251]
# Pixel value at (157,153): [243 247 252]
# Pixel value at (157,154): [244 247 252]
# Pixel value at (157,155): [245 248 253]
# Pixel value at (157,156): [246 249 254]
# Pixel value at (157,157): [248 248 254]
# Pixel value at (157,158): [249 249 255]
# Pixel value at (157,159): [249 249 255]
# Pixel value at (157,160): [244 247 252]
# Pixel value at (157,161): [244 248 253]
# Pixel value at (157,162): [244 248 253]
# Pixel value at (157,163): [244 248 253]
# Pixel value at (157,164): [245 249 254]
# Pixel value at (157,165): [245 249 254]
# Pixel value at (157,166): [245 249 254]
# Pixel value at (157,167): [246 250 255]
# Pixel value at (157,168): [246 250 255]
# Pixel value at (157,169): [246 250 255]
# Pixel value at (158,140): [218 224 229]
# Pixel value at (158,141): [224 230 235]
# Pixel value at (158,142): [222 228 233]
# Pixel value at (158,143): [216 222 227]
# Pixel value at (158,144): [222 228 233]
# Pixel value at (158,145): [223 229 234]
# Pixel value at (158,146): [225 231 236]
# Pixel value at (158,147): [230 234 239]
# Pixel value at (158,148): [234 238 243]
# Pixel value at (158,149): [237 241 246]
# Pixel value at (158,150): [240 243 248]
# Pixel value at (158,151): [242 245 250]
# Pixel value at (158,152): [242 245 250]
# Pixel value at (158,153): [242 245 250]
# Pixel value at (158,154): [245 245 251]
# Pixel value at (158,155): [246 246 252]
# Pixel value at (158,156): [247 247 253]
# Pixel value at (158,157): [249 247 253]
# Pixel value at (158,158): [250 248 254]
# Pixel value at (158,159): [248 248 254]
# Pixel value at (158,160): [244 247 252]
# Pixel value at (158,161): [245 248 253]
# Pixel value at (158,162): [245 248 253]
# Pixel value at (158,163): [245 248 253]
# Pixel value at (158,164): [246 249 254]
# Pixel value at (158,165): [246 249 254]
# Pixel value at (158,166): [246 249 254]
# Pixel value at (158,167): [247 250 255]
# Pixel value at (158,168): [247 250 255]
# Pixel value at (158,169): [247 250 255]
# Pixel value at (159,140): [215 221 226]
# Pixel value at (159,141): [225 231 236]
# Pixel value at (159,142): [222 228 233]
# Pixel value at (159,143): [211 217 222]
# Pixel value at (159,144): [221 227 232]
# Pixel value at (159,145): [222 228 233]
# Pixel value at (159,146): [227 231 236]
# Pixel value at (159,147): [230 234 239]
# Pixel value at (159,148): [234 238 243]
# Pixel value at (159,149): [237 241 246]
# Pixel value at (159,150): [240 244 249]
# Pixel value at (159,151): [241 245 250]
# Pixel value at (159,152): [241 244 249]
# Pixel value at (159,153): [241 244 249]
# Pixel value at (159,154): [242 245 250]
# Pixel value at (159,155): [243 246 251]
# Pixel value at (159,156): [246 246 252]
# Pixel value at (159,157): [246 246 252]
# Pixel value at (159,158): [247 247 253]
# Pixel value at (159,159): [247 247 253]
# Pixel value at (159,160): [244 247 252]
# Pixel value at (159,161): [244 248 253]
# Pixel value at (159,162): [245 248 253]
# Pixel value at (159,163): [244 248 253]
# Pixel value at (159,164): [246 249 254]
# Pixel value at (159,165): [245 249 254]
# Pixel value at (159,166): [246 249 254]
# Pixel value at (159,167): [246 250 255]
# Pixel value at (159,168): [247 250 255]
# Pixel value at (159,169): [246 250 255]

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)


# Display image
plt.imshow(image_rgb)
plt.title("Original Image")
# plt.axis("off")
plt.show()
